# %% [markdown]
# <a href="https://colab.research.google.com/github/profaHeloisaGuimaraes/programacao-python-2025.2/blob/Unidade-I/U1A1_Introdu%C3%A7%C3%A3o_ao_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
valor = 21
resultado_resto = valor % 2
if (resultado_resto == 0):
  print(valor, "É par")
else:
  print(valor,"É ímpar")
# Out:
# 21 É ímpar

# %% [markdown]
# Faça: Resto da Divisão
#  Receba dois números inteiros e mostre o resto da divisão do primeiro pelo segundo.
