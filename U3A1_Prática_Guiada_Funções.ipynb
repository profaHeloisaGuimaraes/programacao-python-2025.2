# %% [markdown]
# <a href="https://colab.research.google.com/github/profaHeloisaGuimaraes/programacao-python-2025.2/blob/Unidade-III/U3A1_Pr%C3%A1tica_Guiada_Fun%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def saudar(nome_pessoa, saudacao='olá', teste=","):
  print(f"{saudacao, teste, nome_pessoa}!")

# print("ola mundo")

# %%
# nome_digitado = input("Digite seu nome: ")
nome_digitado = "Ana"
saudacao_digitada="Hello"

saudar(teste=".", nome_pessoa=nome_digitado)
# Out:
# ('olá', '.', 'Ana')!

# %%
def  calcular_soma(x, y):
  resultado = x + y
  return resultado
  print(resultado)

# %%
resultado_calculo = calcular_soma(10, 57)
print(resultado_calculo)
# Out:
# 67

# %%
def calcular_media(nota1, nota2, nota3=0):
  media_notas = (nota1+nota2+nota3)/3
  return media_notas

# %%
nota1 = 10
nota2 = 5.9
nota3 = 7.8958

media_das_notas = calcular_media(nota1, nota2, 10.5)

print(media_das_notas)
# Out:
# 8.799999999999999
